# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1.    Write a Pandas program to create and display a one-dimensional array-like
# object containing an array of data using Pandas module.

# %%
lis = [1,2,3,4,"No"]
ls = pd.Series(lis)
ls
# Out:
# 0     1
# 1     2
# 2     3
# 3     4
# 4    No
# dtype: object

# %% [markdown]
# Write a Pandas program to convert a Panda module Series to Python list and it's
# type.

# %%
newList = ls.to_list()
print(newList)
print(type(newList))
# Out:
# [1, 2, 3, 4, 'No']
# <class 'list'>

# %% [markdown]
# 3.    Write a Pandas program to compare the elements of the two Pandas Series.

# %%
s1 = pd.Series([1,2,3,4,5])
s2 = pd.Series([1,3,5,7,9])
s1==s2
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# 4.Write a Pandas program to change the data type of given a column or a Series.

# %%
print(type(s1[0]))
s1=s1.astype(float)
print(type(s1[0]))
s1
# Out:
# <class 'numpy.int64'>
# <class 'numpy.float64'>
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# dtype: float64

# %% [markdown]
# 5.    Write a Pandas program to get the powers of an array values element-wise.
# Note: First array elements raised to powers from second array

# %%
df = pd.DataFrame({'X': [78, 85, 96, 80, 86],
        'Y': [84, 94, 89, 83, 86],
        'Z': [86, 97, 96, 72, 83]})
powers = [0, 1, 2, 3, 4]
df2 = df.apply(lambda x: x.pow(powers))
df2
# Out:
#           X         Y         Z
# 0         1         1         1
# 1        85        94        97
# 2      9216      7921      9216
# 3    512000    571787    373248
# 4  54700816  54700816  47458321

# %% [markdown]
# 6.    Write a Pandas program to get the first 3 rows of a given DataFrame.

# %%
exam_data ={'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael',
'Matthew', 'Laura', 'Kevin', 'Jonas'],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19]}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df = pd.DataFrame(exam_data,index=labels)
df[0:3]
# Out:
#    attempts       name qualify  score
# a         1  Anastasia     yes   12.5
# b         3       Dima      no    9.0
# c         2  Katherine     yes   16.5

# %% [markdown]
# 7.    Write a Pandas program to display the default index and set a column as an
# Index in a given dataframe.

# %%
Test_data = [
    ["Streat1", "S001", "V", "Alberto", "Franco", "15/05/2002", 35],
    ["Streat2", "S002", "V", "Gino", "Mcneill", "17/05/2002", 32],
    ["Streat3", "S003", "VI", "Ryan", "Parkes", "16/02/1999", 33],
    ["Streat4", "S004", "VI", "Eesha", "Hinton", "25/09/1998", 30],
    ["Streat5", "S005", "V", "Gino", "Mcneill", "11/05/2002", 31],
    ["Streat6", "S006", "VI", "David", "Parkes", "15/09/1997", 32],
]
column_names = ["StreatNumber", "ID", "V // VI", "First Name", "Last Name", "Date of Birth", "Score"]
df = pd.DataFrame(Test_data, columns=column_names)
df
# Out:
#   StreatNumber    ID V // VI First Name Last Name Date of Birth  Score
# 0      Streat1  S001       V    Alberto    Franco    15/05/2002     35
# 1      Streat2  S002       V       Gino   Mcneill    17/05/2002     32
# 2      Streat3  S003      VI       Ryan    Parkes    16/02/1999     33
# 3      Streat4  S004      VI      Eesha    Hinton    25/09/1998     30
# 4      Streat5  S005       V       Gino   Mcneill    11/05/2002     31
# 5      Streat6  S006      VI      David    Parkes    15/09/1997     32

# %% [markdown]
# 8.    Write a Pandas program to display the default index and set a column as an
# Index in a given dataframe and then reset the index

# %%
df.set_index("StreatNumber",inplace=True)
df
# Out:
#                 ID V // VI First Name Last Name Date of Birth  Score
# StreatNumber
# Streat1       S001       V    Alberto    Franco    15/05/2002     35
# Streat2       S002       V       Gino   Mcneill    17/05/2002     32
# Streat3       S003      VI       Ryan    Parkes    16/02/1999     33
# Streat4       S004      VI      Eesha    Hinton    25/09/1998     30
# Streat5       S005       V       Gino   Mcneill    11/05/2002     31
# Streat6       S006      VI      David    Parkes    15/09/1997     32

# %%
df.reset_index(inplace=True)
df
# Out:
#   StreatNumber    ID V // VI First Name Last Name Date of Birth  Score
# 0      Streat1  S001       V    Alberto    Franco    15/05/2002     35
# 1      Streat2  S002       V       Gino   Mcneill    17/05/2002     32
# 2      Streat3  S003      VI       Ryan    Parkes    16/02/1999     33
# 3      Streat4  S004      VI      Eesha    Hinton    25/09/1998     30
# 4      Streat5  S005       V       Gino   Mcneill    11/05/2002     31
# 5      Streat6  S006      VI      David    Parkes    15/09/1997     32

# %%
newDF = df.copy()
newDF.set_index("Date of Birth",inplace = True)
newDF.sort_index(inplace = True)
newDF
# Out:
#               StreatNumber    ID V // VI First Name Last Name  Score
# Date of Birth
# 11/05/2002         Streat5  S005       V       Gino   Mcneill     31
# 15/05/2002         Streat1  S001       V    Alberto    Franco     35
# 15/09/1997         Streat6  S006      VI      David    Parkes     32
# 16/02/1999         Streat3  S003      VI       Ryan    Parkes     33
# 17/05/2002         Streat2  S002       V       Gino   Mcneill     32
# 25/09/1998         Streat4  S004      VI      Eesha    Hinton     30

# %% [markdown]
# 10.  Write a Pandas program to create a dataframe and set a title or name of the
# index column.

# %%
df.set_index("StreatNumber",inplace= True)
df
# Out:
#                 ID V // VI First Name Last Name Date of Birth  Score
# StreatNumber
# Streat1       S001       V    Alberto    Franco    15/05/2002     35
# Streat2       S002       V       Gino   Mcneill    17/05/2002     32
# Streat3       S003      VI       Ryan    Parkes    16/02/1999     33
# Streat4       S004      VI      Eesha    Hinton    25/09/1998     30
# Streat5       S005       V       Gino   Mcneill    11/05/2002     31
# Streat6       S006      VI      David    Parkes    15/09/1997     32

# %%
DF2 = df.copy()
DF2.index = DF2["ID"]
DF2
# Out:
#         ID V // VI First Name Last Name Date of Birth  Score
# ID
# S001  S001       V    Alberto    Franco    15/05/2002     35
# S002  S002       V       Gino   Mcneill    17/05/2002     32
# S003  S003      VI       Ryan    Parkes    16/02/1999     33
# S004  S004      VI      Eesha    Hinton    25/09/1998     30
# S005  S005       V       Gino   Mcneill    11/05/2002     31
# S006  S006      VI      David    Parkes    15/09/1997     32

# %%
df = df.iloc[0:5]
df
# Out:
#                 ID V // VI First Name Last Name Date of Birth  Score
# StreatNumber
# Streat1       S001       V    Alberto    Franco    15/05/2002     35
# Streat2       S002       V       Gino   Mcneill    17/05/2002     32
# Streat3       S003      VI       Ryan    Parkes    16/02/1999     33
# Streat4       S004      VI      Eesha    Hinton    25/09/1998     30
# Streat5       S005       V       Gino   Mcneill    11/05/2002     31
